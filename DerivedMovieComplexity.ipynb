# %%
from ollama import chat, ChatResponse
import json
import re
import time

# Axiomatic symbol set (expanded to include all referenced characters)
axiomatic_symbols = {
    "CHARACTERS": ["A", "B", "C", "D", "E", "F"],
    "ACTIONS": ["LOVE", "KILL", "WANT", "OWN", "SAVE", "LEAVE", "DIE", "FIGHT", "RULE", "FLEE", "PROTECT", "FOLLOW", "REBEL", "TRAIN"],
    "OBJECTS": ["THRONE", "LIFE", "KINGDOM", "SPICE", "DESTINY", "FAMILY", "PLANET", "POWER"],
    "EMOTIONS": ["GRIEF", "FEAR", "HOPE", "JOY", "SADNESS", "ANGER", "GUILT", "HATE", "AMBITION"],
    "RELATIONS": ["FATHER", "MOTHER", "SON", "FRIEND", "ENEMY", "LOVER", "MENTOR"],
    "MODIFIERS": ["NOT", "BEFORE", "AFTER", "CAUSES", "→", "=", "IF", "WHEN"]
}

# Tracks all derived symbols
derived_symbols = {}

# Store final compression for each fragment
final_compressions = []

# A sequence of Dune synopsis fragments
dune_fragments = [
    "A is the son of B. B is the ruler of planet Arrakis. B is betrayed and killed by C.",
    "A and D flee into the desert. D is A's mother. They survive with help from E.",
    "A learns about his destiny to lead. He begins to have visions of the future.",
    "A trains with E's people and earns their respect.",
    "C continues to rule with cruelty. A plans rebellion.",
    "A fights and defeats C. A becomes ruler of Arrakis.",
    "A marries F, a princess. But he still loves E.",
    "A struggles with guilt and visions of future destruction.",
    "A accepts his role but knows it comes with great sacrifice.",
]

def build_prompt(axioms, derived, story):
    lines = [
        "You are a symbolic compression engine.",
        "Each iteration, you must represent the given synopsis using only the axiomatic and previously defined derived symbols.",
        "You may only define a new derived symbol if it is made purely from already available symbols.",
        "",
        "AXIOMATIC + DERIVED SYMBOLS:"
    ]
    
    for category, symbols in axioms.items():
        lines.append(f"# {category}")
        for s in symbols:
            lines.append(f"- {s}")
    lines.append("")
    
    lines.append("# DERIVED SYMBOLS")
    if not derived:
        lines.append("- None")
    else:
        for k, v in derived.items():
            lines.append(f"- {k} := {v}")
    lines.append("")
    
    lines.append("TASK:")
    lines.append(f"Compress the following scene:")
    lines.append(f"\"{story}\"\n")
    
    lines.append("Output FORMAT:")
    lines.append("- COMPRESSED: [symbolic form]")
    lines.append("- NEW SYMBOLS: [only list newly created symbols]")
    lines.append("  - name := definition")
    
    return "\n".join(lines)

def send_to_ollama(prompt, max_retries=3):
    for attempt in range(max_retries):
        try:
            response: ChatResponse = chat(
                model='llama3.1',  # Change to appropriate model if needed
                messages=[
                    {
                        'role': 'user',
                        'content': prompt,
                    }
                ]
            )
            return response.message.content
        except Exception as e:
            print(f"API Error (attempt {attempt+1}/{max_retries}): {e}")
            if attempt < max_retries - 1:
                time.sleep(2)  # Wait before retrying
            else:
                raise

def parse_response(text):
    # Extract the compressed representation
    compressed_match = re.search(r"COMPRESSED:\s*(.+?)(?:\n|$)", text, re.DOTALL)
    compressed = compressed_match.group(1).strip() if compressed_match else None
    
    # Extract new symbol definitions
    new_defs = {}
    new_symbols_section = re.search(r"NEW SYMBOLS:(.+?)(?:\n\n|$)", text, re.DOTALL)
    
    if new_symbols_section:
        symbol_text = new_symbols_section.group(1)
        for line in symbol_text.strip().splitlines():
            if ":=" in line:
                parts = line.strip().split(":=", 1)
                if len(parts) == 2:
                    key = parts[0].strip("- ").strip()
                    val = parts[1].strip()
                    new_defs[key] = val
    
    return compressed, new_defs

# === MAIN COMPRESSION LOOP ===
print("🚀 Starting symbolic compression of Dune\n")
all_outputs = []
iteration = 1

for fragment_index, story in enumerate(dune_fragments):
    print(f"\n====== PROCESSING FRAGMENT {fragment_index + 1} ======")
    print(f"Text: \"{story}\"")
    
    last_compressed = None
    unchanged_count = 0
    
    for i in range(10):  # Max iterations per fragment (reduced from 50)
        print(f"\n--- ITERATION {iteration} ---")
        prompt = build_prompt(axiomatic_symbols, derived_symbols, story)
        
        try:
            response = send_to_ollama(prompt)
            print(response)
            
            # Save the response for later review
            all_outputs.append(f"ITERATION {iteration}:\n{response}\n")
            
            # Parse the response
            compressed, new_defs = parse_response(response)
            
            if compressed == last_compressed:
                unchanged_count += 1
            else:
                unchanged_count = 0
                last_compressed = compressed
            
            # If we've reached convergence (no new symbols or unchanged for 2 iterations)
            if not new_defs or unchanged_count >= 2:
                print(f"✅ Final compression form reached: {compressed}")
                final_compressions.append(compressed)
                break
                
            # Add new derived symbols
            derived_symbols.update(new_defs)
            
        except Exception as e:
            print(f"Error in iteration {iteration}: {e}")
        
        iteration += 1

print("\n🧠 FINAL DERIVED SYMBOLS:\n")
for name, definition in derived_symbols.items():
    print(f"{name} := {definition}")

print("\n📝 FINAL COMPRESSED NARRATIVE:\n")
for i, compression in enumerate(final_compressions):
    print(f"Fragment {i+1}: {compression}")

# Attempt to create a unified compressed representation
if final_compressions:
    unified_story = " → ".join(final_compressions)
    print("\n🎬 UNIFIED STORY COMPRESSION:")
    print(unified_story)
# Out:
# 🚀 Starting symbolic compression of Dune
#
#
# ====== PROCESSING FRAGMENT 1 ======
# Text: "A is the son of B. B is the ruler of planet Arrakis. B is betrayed and killed by C."
#
# --- ITERATION 1 ---
# # COMPRESSED
# COMPRESSED: A = SON(B), B = RULE(PLANET, PLANET::Arrakis) → KILL(C)
#
# # NEW SYMBOLS:
# - NAME := RULE(definition)
#   - NAME := RULER OF (OBJECT::)
# - OBJECT ::= PLANET
#   - (new axiom)
#
# --- ITERATION 2 ---
# **Iteration 1**
#
# To compress the scene, I'll start by replacing the given text with its symbolic representation.
#
# "A is the son of B." → SON = FRIEND (FATHER:: B)
# "B is the ruler of planet Arrakis." → RULER = NAME (OBJECT :: PLANET:: Arrakis)
# "B is betrayed and killed by C." → BETRAYED = → KILL (LOVER / ENEMY:: C)
#
# **COMPRESSED:** [SON = FRIEND (FATHER:: B) AND RULER = NAME (OBJECT :: PLANET:: Arrakis) CAUSES BETRAYED = → KILL (LOVER / ENEMY:: C)]
# **NEW SYMBOLS:**
# - name := definition
#   - RULER := NAME (OBJECT ::= PLANET)
#   - SON := FRIEND (FATHER ::)
#
# Note that I've only used the given axiomatic and derived symbols, and introduced no new definitions beyond what was required.
#
# **Iteration 2**
#
# In this iteration, I'll aim to simplify the compressed form further.
#
# SON = FRIEND (FATHER:: B) → SON = FATHER (B)
# RULER = NAME (OBJECT ::= PLANET:: Arrakis) → RULER = NAME (OBJECT :: PLANET)
#
# COMPRESSED:** [SON = FATHER (B) AND RULER = NAME (OBJECT :: PLANET) CAUSES BETRAYED = → KILL (LOVER / ENEMY:: C)]
# **NEW SYMBOLS:**
# - None
#
# **Iteration 3**
#
# The compressed form remains the same, but I can now define a new derived symbol for "betrayed".
#
# BETRAYED = → KILL (LOVER / ENEMY:: C) → BETRAYAL = KILL (LOVER / ENEMY::)
#
# COMPRESSED:** [SON = FATHER (B) AND RULER = NAME (OBJECT :: PLANET) CAUSES BETRAYAL = KILL (LOVER / ENEMY:: C)]
# **NEW SYMBOLS:**
# - BETRAYAL := definition
#   - BETRAYAL = KILL (LOVER / ENEMY ::)
#
# The compressed scene now stands at:
#
# COMPRESSED:** [SON = FATHER (B) AND RULER = NAME (OBJECT :: PLANET) CAUSES BETRAYAL = KILL (LOVER / ENEMY:: C)]
# **NEW SYMBOLS:**
# - name := definition
#   - RULER := NAME (OBJECT ::= PLANET)
#   - SON := FRIEND (FATHER ::)
#   - BETRAYAL := definition
#     - BETRAYAL = KILL (LOVER / ENEMY ::)
#
# --- ITERATION 3 ---
# COMPRESSED: [A = SON (B)] AND [B = RULER (PLANET) CAUSES KILL (B, C)]
#
# NEW SYMBOLS:
#
# * None, as all derived symbols are made purely from already available axiomatic and previously defined derived symbols.
# ✅ Final compression form reached: [A = SON (B)] AND [B = RULER (PLANET) CAUSES KILL (B, C)]
#
# ====== PROCESSING FRAGMENT 2 ======
# Text: "A and D flee into the desert. D is A's mother. They survive with help from E."
#
# --- ITERATION 3 ---
# # COMPRESSION
# COMPRESSED: [A, MOTHER = D] FLEE DESERT WITH [E] HELP.
#
# NEW SYMBOLS:
# - MOTHER := RULER OF (FRIEND = RULER OF OBJECT ::= PLANET)
#
# --- ITERATION 4 ---
# After analyzing the given synopsis, I have compressed it using only axiomatic and previously defined derived symbols.
#
# **COMPRESSED:** FLEE (A, D) BEFORE OBJECT : = PLANET → SAVE (A, D) WITH E.
#
# **NEW SYMBOLS:**
#
# * FLEE := PROTECT FROM ENEMY
# * SAVE := PROTECT FROM HARM
#
# Explanation:
# - "D is A's mother" can be represented as MOTHER := RULER OF (FRIEND = RULER OF OBJECT ::= PLANET), which means that D is a ruler of the same object as A, and both are friends.
# - "They survive with help from E" can be represented by SAVE (A, D) WITH E, assuming E provides aid in their survival.
# ✅ Final compression form reached: ** FLEE (A, D) BEFORE OBJECT : = PLANET → SAVE (A, D) WITH E.
#
# ====== PROCESSING FRAGMENT 3 ======
# Text: "A learns about his destiny to lead. He begins to have visions of the future."
#
# --- ITERATION 4 ---
# # COMPRESSION
# COMPRESSED: A → AMBITION (DESTINY = LEAD) → VISION OF FUTURE
#
# # NEW SYMBOLS
# - LEAD := RULER OF (OBJECT ::= PLANET)
# - VISION := HOPE (FUTURE ::=)
#
# Explanation:
# The compressed symbolic form represents the scene "A learns about his destiny to lead. He begins to have visions of the future." by using axiomatic and previously defined derived symbols.
#
# *   The prefix `→` indicates the onset of an action or a change.
# *   `AMBITION (DESTINY = LEAD)` represents A's desire to lead, which is a part of his destiny.
# *   Similarly, `VISION OF FUTURE` represents the visions A has about what will happen in the future.
# ✅ Final compression form reached: A → AMBITION (DESTINY = LEAD) → VISION OF FUTURE
#
# ====== PROCESSING FRAGMENT 4 ======
# Text: "A trains with E's people and earns their respect."
#
# --- ITERATION 4 ---
# COMPRESSED: TRAIN (E, PEOPLE) → RESPECT
#
# NEW SYMBOLS:
#
# * PEOPLE := OBJECT : = PLANET
# * TRAIN := ACTION (OBJECT ::= PLANET, FRIEND ::= SON)
# * RESPECT := EMOTION (FRIEND = RULER OF OBJECT ::= PLANET)
#
# Note that we've used the derived symbol "SON" to represent the relationship between E and their people. We've also defined a new symbol for "PEOPLE" as it is not explicitly listed in the axiomatic symbols, but can be represented using existing ones. The actions of "TRAIN" and "RESPECT" are then described using these newly derived symbols.
#
# --- ITERATION 5 ---
# COMPRESSED:
# *A TRAIN (OBJECT ::= *PEOPLE, FRIEND :: = SON) → RESPECT
#
# NEW SYMBOLS:
#
# * None
#
# Note: The compressed symbolic form uses only the axiomatic and derived symbols provided. No new symbols were introduced beyond what is defined in the original list of derived symbols.
#
# Explanation:
# The scene is represented as follows:
#
# * A trains with E's people, so *TRAIN is used to represent "trains".
# * OBJECT ::= *PEOPLE represents the object being trained, which is E's people.
# * FRIEND ::= SON represents E's son.
# * The action of training E's son earns their respect, so → RESPECT is used to indicate this causal relationship.
# ✅ Final compression form reached: *A TRAIN (OBJECT ::= *PEOPLE, FRIEND :: = SON) → RESPECT
#
# ====== PROCESSING FRAGMENT 5 ======
# Text: "C continues to rule with cruelty. A plans rebellion."
#
# --- ITERATION 5 ---
# COMPRESSED: [C → RULE (OBJECT ::= PLANET), A → REBEL (CAUSES C → RULE)]
#
# NEW SYMBOLS:
#
# - none
#   - No new derived symbols were created. The compression was achieved using existing axiomatic and derived symbols.
#
# Note:
# - 'C' is an abbreviation for a character or object, which is assumed to be the ruler of a planet.
# - 'A' plans a rebellion because C rules with cruelty.
# - We have used → (CAUSES) to indicate causality between events.
# ✅ Final compression form reached: [C → RULE (OBJECT ::= PLANET), A → REBEL (CAUSES C → RULE)]
#
# ====== PROCESSING FRAGMENT 6 ======
# Text: "A fights and defeats C. A becomes ruler of Arrakis."
#
# --- ITERATION 5 ---
# After analyzing the given synopsis, I will attempt to compress it using the axiomatic and derived symbols.
#
# COMPRESSED: FIGHT (A, C) → RULER (A, PLANET ::= Arrakis)
#
# NEW SYMBOLS:
# - NONE
#
# Explanation:
#
# * "A fights and defeats C" can be represented by the action "FIGHT" with A as the actor and C as the recipient.
# * The result of this fight is that A becomes the ruler of a planet, which can be represented using the derived symbol RULER (A, PLANET ::= Arrakis).
# * Since FIGHT implies a causal relationship, we use the implication operator → to indicate that the outcome of the fight is that A becomes the ruler.
#
# Note that the compressed form uses only axiomatic and previously defined derived symbols.
# ✅ Final compression form reached: FIGHT (A, C) → RULER (A, PLANET ::= Arrakis)
#
# ====== PROCESSING FRAGMENT 7 ======
# Text: "A marries F, a princess. But he still loves E."
#
# --- ITERATION 5 ---
# COMPRESSED: LOVE → SON (FATHER = A, MOTHER = F) BUT LOVE (A, E)
#
# NEW SYMBOLS:
#
# * BUT := NOT AND
# * AND := IF (THEN (A, B), THEN (B, C))
#
# --- ITERATION 6 ---
# After analyzing the given scene, I will represent it symbolically using the axiomatic and previously defined derived symbols.
#
# **COMPRESSED:** [LOVE (F = MOTHER), BUT, LOVE (E)]
#
# **NEW SYMBOLS:** None. The compressed form only uses existing symbols.
#
# Breakdown:
#
# * "A marries F" is represented by "[LOVE (F = MOTHER)]", where `LOVE` is an action of being married to a ruler's mother (`MOTHER`).
# * "a princess" is not explicitly mentioned, but it can be inferred from the context.
# * "But he still loves E" is represented by `[BUT] [LOVE (E)]`, where `[BUT]` is the newly derived symbol `BUT := NOT AND`.
#
# Note that no new symbols are created beyond the already defined `BUT`.
# ✅ Final compression form reached: ** [LOVE (F = MOTHER), BUT, LOVE (E)]
#
# ====== PROCESSING FRAGMENT 8 ======
# Text: "A struggles with guilt and visions of future destruction."
#
# --- ITERATION 6 ---
# Here's the compressed representation of the given scene:
#
# COMPRESSED: AMBITION = GRIEF (FUTURE DESTRUCTION)
#
# NEW SYMBOLS:
#
# * FUTURE DESTRUCTION := VISION OF DESTINY
# * VISION := OBJECT (EMOTION = GUILT)
# * DESTINY := LIFE (DESTROYED BY ACTION = KILL OR ACTION = FIGHT)
#
# --- ITERATION 7 ---
# To compress the given scene, I will apply the provided rules to simplify it step by step.
#
# Given scene: "A struggles with guilt and visions of future destruction."
#
# 1. **GUILT** is an axiomatic emotion symbol.
# 2. **VISION** can be derived from the EMOTIONS and OBJECT relation:
#    - VISION := OBJECT (EMOTION = GUILT) => VISION := OBJECT : (EMOTION ::= GUILT)
# 3. Since "vision of future destruction" implies a specific object (DESTINY), we substitute DESTINY in the definition for VISION:
#    - VISION := OBJECT : (EMOTION ::= GUILT) becomes VISION := DESTINATION : (EMOTION ::= GUILT) => FUTURE DESTRUCTION
# 4. Therefore, **FUTURE DESTRUCTION** is an existing derived symbol.
# 5. A "struggle" with something implies a state of conflict or tension:
#    - This can be represented using the emotion of ANGER, which is axiomatic, but we need to link it to GUILT and FUTURE DESTRUCTION.
#    The most straightforward way to do this is by defining a new derived symbol that represents the struggle between emotions or visions:
#    - STRUGGLE := EMOTION (ACTION = WANT OR ACTION = TRY TO CHANGE; OBJECT :: = VISION)
#
# However, since "struggle with" implies an action of resistance against something, we can instead focus on the action of resisting the vision:
#
# 6. The action of struggling is best represented by resisting or fighting the vision:
#    - STRUGGLE := RESIST (OBJECT ::= FUTURE DESTRUCTION)
# 7. Since we're creating a new symbol from existing ones and our initial goal was to compress using given symbols, let's represent A as RULER OF OBJECT : PLANET (from the derived symbol name):
#    - A = RULER
# 8. The struggle or resistance can then be linked to the ruler:
#    - STRUGGLE := RESIST (OBJECT ::= FUTURE DESTRUCTION) becomes
#    - STRUGGLE := RULER RESIST (OBJECT ::= FUTURE DESTRUCTION)
#
# Given this breakdown, we have created a new derived symbol **STRUGGLE**, which is defined as:
#
# - COMPRESSED: [symbolic form] = RULER RESIST (OBJECT ::= FUTURE DESTRUCTION)
# - NEW SYMBOLS:
#   - name := definition
#   - STRUGGLE := RULER RESIST (OBJECT ::= FUTURE DESTRUCTION)
#
# --- ITERATION 8 ---
# To compress the given scene, we'll use the axiomatic and derived symbols to represent it in a more concise symbolic form. We start by analyzing the key elements of the scene:
#
# 1. **A** (the ruler) struggles with two emotions:
#    - **GUILT**: an emotion.
#    - **VISIONS OF FUTURE DESTRUCTION**: the object is **DESTINY**, and the emotion is **GUILT**, so it corresponds to **FUTURE DESTRUCTION**.
#
# The scene involves A's emotional state regarding their understanding or foreboding of future events related to their kingdom, which aligns with the concept of **DESTINY**. A's emotional struggle is represented by **GUILT**, indicating a sense of wrongfulness or regret associated with these visions.
#
# From the given derived symbols and axioms:
#
# - The symbolic form for "A struggles with guilt and visions of future destruction" directly utilizes the concepts of:
#   - **RULER OF (OBJECT ::= PLANET)**: Simplified as `RULER`.
#   - **EMOTION = GUILT**: Simplified as a direct reference to **GUILT**.
#   - **VISION OF DESTINY**: Directly corresponds to **FUTURE DESTRUCTION**.
#
# Combining these, we get:
# - COMPRESSED: `RULER → FUTURE DESTRUCTION`
#
# NEW SYMBOLS (none newly defined in the compression process), but we should note that while not new, it's essential to acknowledge that no additional derived symbols were created for this specific task. The process used existing definitions and axioms directly.
#
# However, if we expand the compressed form slightly to better adhere to the task format without introducing new derived symbols beyond what's explicitly required:
# - We use **RULER** as defined, which simplifies the expression but still adheres strictly to given definitions.
#
# The key takeaway is that no additional derived symbols were created from scratch for this scene; all representations came directly or indirectly from provided axioms and existing derived symbols.
# ✅ Final compression form reached: `RULER → FUTURE DESTRUCTION`
#
# ====== PROCESSING FRAGMENT 9 ======
# Text: "A accepts his role but knows it comes with great sacrifice."
#
# --- ITERATION 8 ---
# **COMPRESSED:**
# RULER OF (OBJECT ::= PLANET) = A
# VISION OF DESTINY → KILL OR FIGHT
# → RULER RESIST (OBJECT ::= VISION OF DESTINY)
#
# **NEW SYMBOLS:**
#
# - RULER RESIST := RESPECT NOT (DESTROYED BY ACTION = KILL OR ACTION = FIGHT)
# - DESTROYED BY := CAUSES (ACTION = KILL OR ACTION = FIGHT)
# ✅ Final compression form reached: **
#
# 🧠 FINAL DERIVED SYMBOLS:
#
# NAME := RULER OF (OBJECT::)
# OBJECT : := PLANET
# name := definition
# RULER := NAME (OBJECT ::= PLANET)
# SON := FRIEND (FATHER ::)
# MOTHER := RULER OF (FRIEND = RULER OF OBJECT ::= PLANET)
# * PEOPLE := OBJECT : = PLANET
# * TRAIN := ACTION (OBJECT ::= PLANET, FRIEND ::= SON)
# * RESPECT := EMOTION (FRIEND = RULER OF OBJECT ::= PLANET)
# * BUT := NOT AND
# * AND := IF (THEN (A, B), THEN (B, C))
# * FUTURE DESTRUCTION := VISION OF DESTINY
# * VISION := OBJECT (EMOTION = GUILT)
# * DESTINY := LIFE (DESTROYED BY ACTION = KILL OR ACTION = FIGHT)
# STRUGGLE := RULER RESIST (OBJECT ::= FUTURE DESTRUCTION)
#
# 📝 FINAL COMPRESSED NARRATIVE:
#
# Fragment 1: [A = SON (B)] AND [B = RULER (PLANET) CAUSES KILL (B, C)]
# Fragment 2: ** FLEE (A, D) BEFORE OBJECT : = PLANET → SAVE (A, D) WITH E.
# Fragment 3: A → AMBITION (DESTINY = LEAD) → VISION OF FUTURE
# Fragment 4: *A TRAIN (OBJECT ::= *PEOPLE, FRIEND :: = SON) → RESPECT
# Fragment 5: [C → RULE (OBJECT ::= PLANET), A → REBEL (CAUSES C → RULE)]
# Fragment 6: FIGHT (A, C) → RULER (A, PLANET ::= Arrakis)
# Fragment 7: ** [LOVE (F = MOTHER), BUT, LOVE (E)]
# Fragment 8: `RULER → FUTURE DESTRUCTION`
# Fragment 9: **
#
# 🎬 UNIFIED STORY COMPRESSION:
# [A = SON (B)] AND [B = RULER (PLANET) CAUSES KILL (B, C)] → ** FLEE (A, D) BEFORE OBJECT : = PLANET → SAVE (A, D) WITH E. → A → AMBITION (DESTINY = LEAD) → VISION OF FUTURE → *A TRAIN (OBJECT ::= *PEOPLE, FRIEND :: = SON) → RESPECT → [C → RULE (OBJECT ::= PLANET), A → REBEL (CAUSES C → RULE)] → FIGHT (A, C) → RULER (A, PLANET ::= Arrakis) → ** [LOVE (F = MOTHER), BUT, LOVE (E)] → `RULER → FUTURE DESTRUCTION` → **

# %%
derived_symbols
# Out:
# {'NAME': 'RULER OF (OBJECT::)',
#  'OBJECT :': 'PLANET',
#  'name': 'definition',
#  'RULER': 'NAME (OBJECT ::= PLANET)',
#  'SON': 'FRIEND (FATHER ::)',
#  'MOTHER': 'RULER OF (FRIEND = RULER OF OBJECT ::= PLANET)',
#  '* PEOPLE': 'OBJECT : = PLANET',
#  '* TRAIN': 'ACTION (OBJECT ::= PLANET, FRIEND ::= SON)',
#  '* RESPECT': 'EMOTION (FRIEND = RULER OF OBJECT ::= PLANET)',
#  '* BUT': 'NOT AND',
#  '* AND': 'IF (THEN (A, B), THEN (B, C))',
#  '* FUTURE DESTRUCTION': 'VISION OF DESTINY',
#  '* VISION': 'OBJECT (EMOTION = GUILT)',
#  '* DESTINY': 'LIFE (DESTROYED BY ACTION = KILL OR ACTION = FIGHT)',
#  'STRUGGLE': 'RULER RESIST (OBJECT ::= FUTURE DESTRUCTION)'}
